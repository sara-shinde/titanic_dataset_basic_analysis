# %%
import sys
print(sys.executable)

# %%
import pandas as pd

# %% [markdown]
# The notebook is in notebooks, so the relative path is set w.r.t to the notebook

# %%
dataset = pd.read_csv("../data/raw/train.csv")

# %%
dataset.head()

# %%
dataset.shape

# %% [markdown]
# We have 891 passengers, and 12 attributes about each one of them

# %% [markdown]
# Data Dictionary
# Variable	Definition	Key
# survival	Survival	0 = No, 1 = Yes
# pclass	Ticket class	1 = 1st, 2 = 2nd, 3 = 3rd
# sex	Sex
# Age	Age in years
# sibsp	# of siblings / spouses aboard the Titanic
# parch	# of parents / children aboard the Titanic
# ticket	Ticket number
# fare	Passenger fare
# cabin	Cabin number
# embarked	Port of Embarkation	C = Cherbourg, Q = Queenstown, S = Southampton
# Variable Notes
# pclass: A proxy for socio-economic status (SES)
# 1st = Upper
# 2nd = Middle
# 3rd = Lower
#
# age: Age is fractional if less than 1. If the age is estimated, is it in the form of xx.5
#
# sibsp: The dataset defines family relations in this way...
# Sibling = brother, sister, stepbrother, stepsister
# Spouse = husband, wife (mistresses and fiancés were ignored)
#
# parch: The dataset defines family relations in this way...
# Parent = mother, father
# Child = daughter, son, stepdaughter, stepson
# Some children travelled only with a nanny, therefore parch=0 for them.

# %% [markdown]
# Let us see how many people survived and how many did not.

# %%
dataset.loc[dataset.Survived == 0]

# %%
dataset.loc[dataset.Survived == 1]

# %% [markdown]
# 342 people survived, and 549 people did not survive

# %%
print(342 + 549)

# %% [markdown]
# 891 = 342 + 549. Which means, we have the survival data of all passengers.

# %%
dataset.loc[dataset.Sex == "female"]

# %%
dataset.loc[dataset.Sex == "male"]

# %%
print(577 + 314)

# %% [markdown]
# The dataset has 314 females and 577 males. 577 + 314 = 891. So each person's gender is entered.

# %%
dataset.loc[dataset.Embarked == "S"]

# %%
dataset.loc[dataset.Embarked == "C"]

# %%
dataset.loc[dataset.Embarked == "Q"]

# %%
print(77 + 168 + 644)

# %%
dataset.loc[dataset.Embarked.isnull()]

# %% [markdown]
# 2 passengers don't have embarkement places listed, 77 passengers embarked in Queensland, 168 passengers embarked at Cherbourg, 644 passengers embarked at Southampton.

# %%
dataset.loc[dataset.Pclass.isnull()]

# %%
dataset.loc[dataset.Pclass == 1]

# %%
dataset.loc[dataset.Pclass == 2]

# %%
dataset.loc[dataset.Pclass == 3]

# %% [markdown]
# All passengers have their passenger class listed. 216 passengers had first class tickets, 184 passengers had 2nd class tickets, 491 passengers had 3rd class tickets.

# %% [markdown]
# Below is a pandas series containing the passenger name:

# %%
dataset.Name

# %%
dataset.head()

# %%
fare_series = dataset.loc[dataset.Fare.notna()]

# %%
dataset.loc[dataset.Fare.isna()]

# %%
fare_series.head()

# %%
fare_series.Fare.describe()

# %%
dataset.Fare.describe()

# %% [markdown]
# All passengers have the fares listed. Above are the fare statistics.

# %% [markdown]
# Below are the age statistics for the 714 passengers who had their ages listed. 177 did not have their ages listed.

# %%
dataset.Age.describe()

# %%
dataset.loc[dataset.Age.isna()]

# %%
print(177 + 714)

# %% [markdown]
# Survival, class, sex, cabin and embarkment statistics can be probably be calculated more easily.

# %%
dataset.Survived.unique()

# %%
dataset.Survived.value_counts()

# %%
dataset.Sex.unique()

# %%
dataset.Sex.value_counts()

# %%
dataset.Pclass.unique()

# %%
dataset.Pclass.value_counts()

# %%
dataset.Embarked.unique()

# %%
dataset.Embarked.value_counts()
